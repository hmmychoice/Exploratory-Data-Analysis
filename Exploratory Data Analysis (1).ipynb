# %% [raw]
# Harshita Mehta

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# AIM: Performing ‘Exploratory Data Analysis’ on the provided dataset ‘SampleSuperstore’ and finding the areas where more work can be done in order to increase the profit.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("The libraries are imported")
# Out:
# The libraries are imported

# %% [markdown]
# # Import Dataset

# %%
data=pd.read_csv("C://Users//harsh//Desktop//SampleSuperstore.csv")
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# # Explore the Dataset

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# # Visualisation

# %%
data.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001CAAEA88588>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(8,5))
correlation=data.corr()
sns.heatmap(correlation,annot=True)

# %%
plt.figure()
sns.pairplot(data)

# %%
plt.figure(figsize=(30,13))
plt.plot(data['Profit'], color='red')
plt.grid(alpha=0.3)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x='Discount',y='Profit',data=data)
plt.legend('Profit')
plt.grid(alpha=0.3)

# %% [markdown]
# # Distribution of segments and ship mode

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.countplot('Segment',data=data)
plt.title('DISTRIBUTION OF SEGMENTS')
plt.xlabel('SEGMENT',fontsize=12)
plt.ylabel('COUNT',fontsize=12)
plt.grid(alpha=0.3)
plt.subplot(1,2,2)
sns.countplot('Ship Mode',data=data)
plt.title('DISTRIBUTION OF SHIP MODE')
plt.ylabel('COUNT',fontsize=12)
plt.xlabel('SHIP MODE',fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
print("Consumer are the highest buyer of goods and Home Ofiice are the least buyers")
print("Standard class is the highest mode for shipping goods but same day mode is the least")
# Out:
# Consumer are the highest buyer of goods and Home Ofiice are the least buyers
# Standard class is the highest mode for shipping goods but same day mode is the least

# %% [markdown]
# # Distribution among states

# %%
plt.figure(figsize=(30,10))
sns.countplot(data['State'])
plt.xticks(fontsize=16,rotation=90)
plt.ylabel('COUNTS',fontsize=20)
plt.xlabel('STATES',fontsize=20)
plt.title('DISTRIBUTION OF STATES',fontsize=25);
plt.grid(alpha=0.3)

# %%
print("California has the highest rate of buyers in US")
# Out:
# California has the highest rate of buyers in US

# %% [markdown]
# # Distribution based on Category/ Sub-Categories

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,1,1)
sns.countplot('Category',data=data);
plt.title('DISTRIBUTION OF CATEGORY')
plt.xlabel('CATEGORY')
plt.ylabel('COUNT')
plt.grid(alpha=0.3)
plt.subplot(2,1,2)
sns.countplot('Sub-Category',data=data);
plt.title('DISTRIBUTION OF SUB-CATEGORY')
plt.xlabel('SUB-CATEGORY')
plt.ylabel('COUNT')
plt.grid(alpha=0.3)

# %%
print(" Office supplies has the highest rate of shippings in total. Binders has the highest shipping count while copiers has the least shipping count under office supplies.")
# Out:
#  Office supplies has the highest rate of shippings in total. Binders has the highest shipping count while copiers has the least shipping count under office supplies.

# %% [markdown]
# # Distribution of regions based on category

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1)
sns.countplot('Region',data=data)
plt.title('DISTRIBUTION OF REGIONS')
plt.xlabel('REGION',fontsize=12)
plt.ylabel('COUNT',fontsize=12)
plt.grid(alpha=0.3)
plt.subplot(1,2,2)
sns.countplot('Region',hue='Category',data=data)
plt.title('DISTRIBUTION OF REGIONS BASED ON CATEGORY')
plt.ylabel('COUNT',fontsize=12)
plt.xlabel('REGION',fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
print("Western state has highest rate of buyers and southern region has the least rate of buyers")
# Out:
# Western state has highest rate of buyers and southern region has the least rate of buyers

# %%
plt.figure(figsize=(18,10))
sns.countplot('Category',hue='Sub-Category',data=data);
plt.title('DISTRIBUTION OF SUB-CATEGORY')
plt.xlabel('SUB-CATEGORY')
plt.ylabel('COUNT')
plt.grid(alpha=0.3)

# %% [markdown]
# # Profit Distribution based on different states

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=data['State'].sort_values(ascending=True),y=data['Profit'])
plt.title('DISTRIBUTION OF PROFITS BASED ON STATES', fontsize=20)
plt.xticks(rotation=90, fontsize=15);
plt.xlabel('STATE',fontsize=15)
plt.ylabel('PROFIT',fontsize=15)
plt.grid(alpha=0.3)

# %% [markdown]
# # Profit distribution based on different regions

# %%
C=data[data['Region']=='Central']
E=data[data['Region']=='East']
W=data[data['Region']=='West']
S=data[data['Region']=='South']

plt.figure(figsize=(20,5))
sns.barplot(x=C['State'].sort_values(ascending=True),y=C['Profit'])
plt.title('DISTRIBUTION OF PROFITS BASED ON CENTRAL REGION', fontsize=20)
plt.xticks(rotation=90, fontsize=15);
plt.xlabel('STATE',fontsize=15)
plt.ylabel('PROFIT',fontsize=15)
plt.grid(alpha=0.3)
plt.figure(figsize=(20,5))
sns.barplot(x=E['State'].sort_values(ascending=True),y=E['Profit'])
plt.title('DISTRIBUTION OF PROFITS BASED ON EASTERN REGION', fontsize=20)
plt.xticks(rotation=90, fontsize=15);
plt.xlabel('STATE',fontsize=15)
plt.ylabel('PROFIT',fontsize=15)
plt.grid(alpha=0.3)
plt.figure(figsize=(20,5))
sns.barplot(x=W['State'].sort_values(ascending=True),y=W['Profit'])
plt.title('DISTRIBUTION OF PROFITS BASED ON WESTERN REGION', fontsize=20)
plt.xticks(rotation=90, fontsize=15);
plt.xlabel('STATE',fontsize=15)
plt.ylabel('PROFIT',fontsize=15)
plt.grid(alpha=0.3)
plt.figure(figsize=(20,5))
sns.barplot(x=S['State'].sort_values(ascending=True),y=S['Profit'])
plt.title('DISTRIBUTION OF PROFITS BASED ON SOUTHERN REGION', fontsize=20)
plt.xticks(rotation=90, fontsize=15);
plt.xlabel('STATE',fontsize=15)
plt.ylabel('PROFIT',fontsize=15)
plt.grid(alpha=0.3)
